# %%
legs = {
         ("upd","admu"):{
             "travel_time_mins":10
         },
         ("admu","dlsu"):{
             "travel_time_mins":35
         },
         ("dlsu","ust"):{
             "travel_time_mins":20
         },
         ("ust","upd"):{
             "travel_time_mins":45
         },
    }
    

def eta(source, destination, legs):
    
    output = '' # Define the variable 'output'
    if (str(source),str(destination)) in legs.keys(): # Inputs exactly match the data in the dictionary
        output = legs[str(source),str(destination)]['travel_time_mins'] # Output eta based on the dictionary data

    else: # Inputs do not exactly match the data in the dictionary
        
        set_of_all_locations = set() # Create a new set containing all universities
        for tuple_key in legs.keys(): # Each tuple key within the dictionary 'legs'
            for place in tuple_key: # Each element of the key within the tuple
                set_of_all_locations.add(place)
                break
        # print(set_of_all_locations) # --> {upd, admu, dlsu} in the original legs dictionary
        
        
        # Group all the places in order (assumption: order of the left strings are arranged in order)
        list_of_all_locations = []
        for tuple_key in legs.keys():
            for place in tuple_key:
                list_of_all_locations.append(place)
                break
        # print(list_of_all_locations) # --> ['upd','admu','dlsu','ust']
        
        
        # list_of_all_locations.extend(set_of_all_locations)
        # print(list_of_all_locations) # Must be [dlsu, ust, upd, admu] in exact order, but placing may be different
        
        # Getting the left string of the key tuple
        source_mention_count = 0
        if source_mention_count < 1:
            if (str(source) == place):
                source_mention_count += 1
                source == place # source
        # print(source)        

        # Getting the right string of the key tuple
        destination_mention_count = 0
        if destination_mention_count < 1:
            if (str(destination) == place):
                destination_mention_count += 1
                destination == place # destination
        # print(destination)        
        
        
        # Only consider the places in between source and destination
        # print(list_of_all_locations.index(str(destination)))
        # print(list_of_all_locations.index(str(source)))
        
        # Count the number of locations that the vehicle needs to go to
        # print(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1)
        # print((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 2)) NO, DO NOT USE THIS
        
        # print(list_of_all_locations.index(str(destination))) # 3
        # print(list_of_all_locations.index(str(source))) # 0
        # print((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1)) # 4
        # print(list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]) 
        # print(list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]) 

        # Conditionals: given the number of locations that the vehicle will need to go to
        if ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 3):
            # 1 Intermediary point between 2 places (Total places to pass through: 3)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2] 
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 4):
            # 2 Intermediary points between 2 places (Total places to pass through: 4)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2] 
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 5):
            # 3 Intermediary points between 2 places (Total places to pass through: 5)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 6):
            # 4 Intermediary points between 2 places (Total places to pass through: 6)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 7):
            # 5 Intermediary points between 2 places (Total places to pass through: 7)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2] 
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 8):
            # 6 Intermediary points between 2 places (Total places to pass through: 8)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 9):
            # 7 Intermediary points between 2 places (Total places to pass through: 9)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 10):
            # 8 Intermediary points between 2 places (Total places to pass through: 10)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 11):
            # 9 Intermediary points between 2 places (Total places to pass through: 11)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 12):
            # 10 Intermediary points between 2 places (Total places to pass through: 12)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 13):
            # 11 Intermediary points between 2 places (Total places to pass through: 13)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 14):
            # 12 Intermediary points between 2 places (Total places to pass through: 14)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 14):
            # 13 Intermediary points between 2 places (Total places to pass through: 15)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 15):
            # 14 Intermediary points between 2 places (Total places to pass through: 16)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 16):
            # 15 Intermediary points between 2 places (Total places to pass through: 17)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 17):
            # 16 Intermediary points between 2 places (Total places to pass through: 18)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            intermediary_point_16 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 15]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 18):
            # 17 Intermediary points between 2 places (Total places to pass through: 19)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            intermediary_point_16 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 15]
            intermediary_point_17 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 16]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 19):
            # 18 Intermediary points between 2 places (Total places to pass through: 20)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            intermediary_point_16 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 15]
            intermediary_point_17 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 16]
            intermediary_point_18 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 17]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 20):
            # 19 Intermediary points between 2 places (Total places to pass through: 21)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            intermediary_point_16 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 15]
            intermediary_point_17 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 16]
            intermediary_point_18 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 17]
            intermediary_point_19 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 18]
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 21):
            # 20 Intermediary points between 2 places (Total places to pass through: 22)
            intermediary_point_1 = list_of_all_locations[((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2]
            intermediary_point_2 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 1]
            intermediary_point_3 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 2]
            intermediary_point_4 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 3]
            intermediary_point_5 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 4]
            intermediary_point_6 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 5]
            intermediary_point_7 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 6]
            intermediary_point_8 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 7]
            intermediary_point_9 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 8]
            intermediary_point_10 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 9]
            intermediary_point_11 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 10]
            intermediary_point_12 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 11]
            intermediary_point_13 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 12]
            intermediary_point_14 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 13]
            intermediary_point_15 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 14]
            intermediary_point_16 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 15]
            intermediary_point_17 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 16]
            intermediary_point_18 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 17]
            intermediary_point_19 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 18]
            intermediary_point_20 = list_of_all_locations[(((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) // 2) + 19]
            
        # Now that we know ('source'), ('intermediary_point_1'), ('intermediary_point_x') and ('destination'), we can now compute for the 'eta':
        # Add the eta from (source to intermediary_point_1) and (intemediary_point_1 and intemediary_point_2) ... and (intermediary_point_X and destination):
        if ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 3):
            # End at intermediary_point_1
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + ((legs[str(intermediary_point_1),str(destination)]['travel_time_mins']))
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 4):
            # End at intermediary_point_2
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(destination)]['travel_time_mins'])
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 5):
            # End at intermediary_point_3
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(destination)]['travel_time_mins'])
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 6):
            # End at intermediary_point_4
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(destination)]['travel_time_mins'])
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 7):
            # End at intermediary_point_5
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(destination)]['travel_time_mins'])
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 8):
            # End at intermediary_point_6
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(destination)]['travel_time_mins'])
        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 9):
            # End at intermediary_point_7
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(destination)]['travel_time_mins'])

        
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 10):
            # End at intermediary_point_8
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 11):
            # End at intermediary_point_9
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 12):
            # End at intermediary_point_10
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(destination)]['travel_time_mins'])

            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 13):
            # End at intermediary_point_11
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(destination)]['travel_time_mins'])

            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 14):
            # End at intermediary_point_12
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) +(legs[str(intermediary_point_12),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 15):
            # End at intermediary_point_13
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 16):
            # End at intermediary_point_14
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 17):
            # End at intermediary_point_15
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(intermediary_point_15)]['travel_time_mins']) + (legs[str(intermediary_point_15),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 18):
            # End at intermediary_point_16
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(intermediary_point_15)]['travel_time_mins']) + (legs[str(intermediary_point_15),str(intermediary_point_16)]['travel_time_mins']) + (legs[str(intermediary_point_16),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 19):
            # End at intermediary_point_17
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(intermediary_point_15)]['travel_time_mins']) + (legs[str(intermediary_point_15),str(intermediary_point_16)]['travel_time_mins']) + (legs[str(intermediary_point_16),str(intermediary_point_17)]['travel_time_mins']) + (legs[str(intermediary_point_17),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 20):
            # End at intermediary_point_18
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(intermediary_point_15)]['travel_time_mins']) + (legs[str(intermediary_point_15),str(intermediary_point_16)]['travel_time_mins']) + (legs[str(intermediary_point_16),str(intermediary_point_17)]['travel_time_mins']) + (legs[str(intermediary_point_17),str(intermediary_point_18)]['travel_time_mins']) + (legs[str(intermediary_point_18),str(destination)]['travel_time_mins'])
            
        elif ((((list_of_all_locations.index(str(destination))) - (list_of_all_locations.index(str(source)))) + 1) == 21):
            # End at intermediary_point_19
            output = (legs[str(source),str(intermediary_point_1)]['travel_time_mins']) + (legs[str(intermediary_point_1),str(intermediary_point_2)]['travel_time_mins']) + (legs[str(intermediary_point_2),str(intermediary_point_3)]['travel_time_mins']) + (legs[str(intermediary_point_3),str(intermediary_point_4)]['travel_time_mins']) + (legs[str(intermediary_point_4),str(intermediary_point_5)]['travel_time_mins']) + (legs[str(intermediary_point_5),str(intermediary_point_6)]['travel_time_mins']) + (legs[str(intermediary_point_6),str(intermediary_point_7)]['travel_time_mins']) + (legs[str(intermediary_point_7),str(intermediary_point_8)]['travel_time_mins']) + (legs[str(intermediary_point_8),str(intermediary_point_9)]['travel_time_mins']) + (legs[str(intermediary_point_9),str(intermediary_point_10)]['travel_time_mins']) + (legs[str(intermediary_point_10),str(intermediary_point_11)]['travel_time_mins']) + (legs[str(intermediary_point_11),str(intermediary_point_12)]['travel_time_mins']) + (legs[str(intermediary_point_12),str(intermediary_point_13)]['travel_time_mins']) + (legs[str(intermediary_point_13),str(intermediary_point_14)]['travel_time_mins']) + (legs[str(intermediary_point_14),str(intermediary_point_15)]['travel_time_mins']) + (legs[str(intermediary_point_15),str(intermediary_point_16)]['travel_time_mins']) + (legs[str(intermediary_point_16),str(intermediary_point_17)]['travel_time_mins']) + (legs[str(intermediary_point_17),str(intermediary_point_18)]['travel_time_mins']) + (legs[str(intermediary_point_18),str(intermediary_point_19)]['travel_time_mins']) + (legs[str(intermediary_point_19),str(destination)]['travel_time_mins'])
        
        
        # WHAT IF THE LOCATIONS ARE NOT IN THE ORDER OF THE LIST?
        if ((list_of_all_locations.index(str(source))) > (list_of_all_locations.index(str(destination)))):
            print(list_of_all_locations.index(str(source)) - len(list_of_all_locations)) # Negative index of source
            print(list_of_all_locations.index(str(destination)) - len(list_of_all_locations)) # Negative index of destination
            
        
    return output         
            
# print(eta('upd','admu', legs))  # 10 CORRECT
# print(eta('admu','dlsu', legs)) # 35 CORRECT
# print(eta('upd','dlsu', legs))  # 45 CORRECT
# print(eta('upd', 'ust', legs))  # 65 CORRECT
# print(eta('ust','upd', legs))   # 45 CORRECT


# PROBLEM: 
# print(list_of_all_locations) # --> ['upd','admu','dlsu','ust']
# consider using the if conditional (index from the right side: negative index)??

print(eta('dlsu','upd', legs))  # 65
# print(eta('dlsu','admu', legs)) # 75
# print(eta('admu','upd', legs))  # 90
# print(eta('ust','admu', legs))  # 55
# Out:
# -2
# -4
